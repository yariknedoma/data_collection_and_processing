# %%
import pandas as pd

# %%
df = pd.read_csv('hh-python')
df
# Out:
#                                                    name  salary_min  \
# 0                      Аналитик данных (Data scientist)     90000.0
# 1                                       DevOps Engineer    170000.0
# 2                                         Data engineer         NaN
# 3                                        Data Scientist         NaN
# 4                                         Data Engineer         NaN
# ...                                                 ...         ...
# 1995                                        QA Engineer         NaN
# 1996  Ведущий веб-тестировщик (ручной) в международн...    100000.0
# 1997  Python разработчик в SberDevices (направление ...         NaN
# 1998                                 Системный аналитик    180000.0
# 1999                    Team Lead/Senior Data Scientist         NaN
#
#       salary_max salary_currency                                         link  \
# ...

# %%
df.isnull().sum()
# Out:
# name                  0
# salary_min         1481
# salary_max         1597
# salary_currency    1391
# link                  0
# source                0
# company               0
# city                566
# dtype: int64

# %%
df.groupby('salary_currency')[['salary_max', 'salary_min']].agg(['min', 'max'])
# Out:
#                 salary_max           salary_min
#                        min       max        min       max
# salary_currency
# EUR                 2800.0    5800.0     2000.0    4100.0
# KZT               400000.0  800000.0   180000.0  500000.0
# USD                 1000.0   15000.0      500.0   10000.0
# грн.                4000.0    4000.0     3000.0    3000.0
# руб.               25000.0  400000.0    15000.0  350000.0
